# %% [markdown]
# # Exploring eBay Car Sales Data
#
# In this guided project, we'll work with a dataset of used cars from eBay Kleinanzeigen, a [classifieds](https://en.wikipedia.org/wiki/Classified_advertising) section of the German eBay website.
#
# The dataset was originally [scraped](http://en.wikipedia.org/wiki/Web_scraping) and uploaded to Kaggle. It is currently available [here](https://www.kaggle.com/datasets/sijovm/used-cars-data-from-ebay-kleinanzeigen).

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin-1")
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %% [markdown]
# So, the dataset has 20 columns and contains mostly string values. It also has some strings stored as a string.

# %% [markdown]
# #  Cleaning Column Names

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# We'll make a few changes here:
#
# * Change the columns from camelcase to snakecase.
# * Change a few wordings to more accurately describe the columns.

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test', 'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model', 'odometer', 'registration_month', 'fuel_type', 'brand', 'unrepaired_damage', 'ad_created', 'num_photos', 'postal_code', 'last_seen']
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# ## Initial Exploration and Cleaning

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-19 17:36:18  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# * `seller` and `offer_type` is almost identical looking.
# * There is something odd about the `num_photos` columns.

# %%
autos["num_photos"].value_counts()
# Out:
# num_photos
# 0    50000
# Name: count, dtype: int64

# %% [markdown]
# Looking at the result it is evident that all of the values in `num_photos` is 0. We will drop this column along with seller and offer_type columns.

# %%
autos = autos.drop(["num_photos", "seller", "offer_type"], axis = 1)

# %%
print(autos["price"])
# Out:
# 0         $5,000
# 1         $8,500
# 2         $8,990
# 3         $4,350
# 4         $1,350
#           ...
# 49995    $24,900
# 49996     $1,980
# 49997    $13,200
# 49998    $22,900
# 49999     $1,250
# Name: price, Length: 50000, dtype: object

# %%
autos["price"] = autos["price"].str.replace("$", "").str.replace(",", "").astype(int)
autos["price"].head()
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: int64

# %%
autos["odometer"].head()
# Out:
# 0    150,000km
# 1    150,000km
# 2     70,000km
# 3     70,000km
# 4    150,000km
# Name: odometer, dtype: object

# %%
autos["odometer"] = autos["odometer"].str.replace("km", "").str.replace(",", "").astype(int)
autos.rename({"odometer" : "odometer_km"}, axis = 1, inplace = True)
autos["odometer_km"].head()
# Out:
# 0    150000
# 1    150000
# 2     70000
# 3     70000
# 4    150000
# Name: odometer_km, dtype: int64

# %% [markdown]
# ## Exploring the Odometer and Price Columns

# %%
autos["odometer_km"].unique()
# Out:
# array([150000,  70000,  50000,  80000,  10000,  30000, 125000,  90000,
#         20000,  60000,   5000, 100000,  40000])

# %%
autos["odometer_km"].value_counts()
# Out:
# odometer_km
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: count, dtype: int64

# %% [markdown]
# There are more cars with high mileage than lower ones.

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %% [markdown]
# So, this price columns has total of 2357 unique rows.

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %% [markdown]
# The highest price is odd it says it is 100 millions.

# %%
autos["price"].value_counts().head(10)
# Out:
# price
# 0       1421
# 500      781
# 1500     734
# 2500     643
# 1000     639
# 1200     639
# 600      531
# 800      498
# 3500     498
# 2000     460
# Name: count, dtype: int64

# %% [markdown]
# There seem to be 1421 cars priced at 0$. We will have to removes those rows.

# %%
autos["price"].value_counts().sort_index(ascending = False).head(10)
# Out:
# price
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# Name: count, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending=True).head(20)
# Out:
# price
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# Name: count, dtype: int64

# %% [markdown]
# eBay is an auction site, there could legitimately be items where the opening bid is
# 1, we will keep 1 item but remove anything above $350,000, since it seems that prices increase steadily to that number and then jump up to less realistic numbers.

# %%
autos = autos[autos["price"].between(1, 351000)]
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Exploring the Date Columns
#
# The following columns contain date information:
#
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website

# %%
autos[["date_crawled", "ad_created", "last_seen"]][0:6]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50
# 5  2016-03-21 13:47:45  2016-03-21 00:00:00  2016-04-06 09:45:21

# %%
autos["date_crawled"].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# date_crawled
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: proportion, dtype: float64

# %% [markdown]
# In march and april the site was crawled daily with uniform distribution of listings.

# %%
autos["ad_created"].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# ad_created
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
#                 ...
# 2016-04-03    0.038855
# 2016-04-04    0.036858
# 2016-04-05    0.011819
# 2016-04-06    0.003253
# 2016-04-07    0.001256
# Name: proportion, Length: 76, dtype: float64

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# These columns suggests that the minimum year of a car being registered is `1000`, the year in which the car wasn't even invented. The maximum value `9999` which is further in future.

# %% [markdown]
# ## Dealing with Incorrect Registration Year Data
#
# A car can't be first registered after the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.

# %%
autos = autos[autos["registration_year"].between(1900,2016)]
autos["registration_year"].value_counts(normalize=True).head(10)
# Out:
# registration_year
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# Name: proportion, dtype: float64

# %% [markdown]
# So most of the vehicles were registred in late 90's and 2000's.

# %% [markdown]
# ## Exploring Price by Brand

# %%
autos["brand"].value_counts(normalize = True)
# Out:
# brand
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# mitsubishi        0.008226
# honda             0.007840
# kia               0.007069
# alfa_romeo        0.006641
# porsche           0.006127
# suzuki            0.005934
# chevrolet         0.005698
# chrysler          0.003513
# dacia             0.002635
# daihatsu          0.002506
# jeep              0.002271
# subaru            0.002142
# land_rover        0.002099
# saab              0.001649
# ...

# %% [markdown]
# The top brand is volkswagen. It seems to be the most populer brand with double the amount of cars than the brand after it. There are lots of brands that don't have a significant percentage of listings, so we will limit our analysis to brands representing more than 5% of total listings.

# %%
brand_count = autos["brand"].value_counts(normalize = True)
common_brands = brand_count[brand_count > 0.05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object', name='brand')

# %%
brand_mean_price = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_price[brand] = int(mean_price)
    
brand_mean_price
# Out:
# {'volkswagen': 5402,
#  'bmw': 8332,
#  'opel': 2975,
#  'mercedes_benz': 8628,
#  'audi': 9336,
#  'ford': 3749}

# %% [markdown]
# Of the top 6 brands, there is a distinct price gap:
#
# * Audi, BMW and Mercedes Benz are more expensive
# * Ford and Opel are less expensive
# * Volkswagen is in between - this may explain its popularity, it may be a 'best of 'both worlds' option.

# %% [markdown]
# ## Storing Aggregate Data in a DataFrame
#
# ### Exploring Mileage

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_mileage = brand_only["odometer_km"].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending = False)
mean_price = pd.Series(brand_mean_price).sort_values(ascending = False)

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132572
# mercedes_benz        130788
# opel                 129310
# audi                 129157
# volkswagen           128707
# ford                 124266
